# %% [markdown]
# # Milestone 4: Project Presentation
#
# ## Overview
# In this notebook, we prepare the final project presentation, including:
# - Code structure
# - Solver performance
# - Results comparison
#
# ## Data Visualization

# %%
import matplotlib.pyplot as plt
from utils import load_measurements

# Load data
measurements = load_measurements("../data/measurements.npy")

plt.figure(figsize=(12, 6))
plt.plot(measurements, '-o', label='Measurements')
plt.title("Pyridine Problem - Measurement Data")
plt.xlabel("Interval")
plt.ylabel("Concentration")
plt.legend()
plt.show()
